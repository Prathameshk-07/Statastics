# %%
import pandas as pd
import  numpy as  np
list=[]

data=[72,85,91,68,85,77,85,9062,95]
df=pd.DataFrame(data, columns=["data"])
Median=np.median(data)
mode=df["data"].mode()
mode=mode[0]
freq=df["data"].value_counts()
sort=df.sort_values("data", ascending=True, ignore_index=True)
list.append(sort)

print("Mode:", mode)
print("Median:", Median)
# print("Frequency Distribution:")
# print(freq)
print(df.describe())
print(list)
# Out:
# Mode: 85
# Median: 85.0
#               data
# count     9.000000
# mean   1080.000000
# std    2993.262476
# min      68.000000
# 25%      77.000000
# 50%      85.000000
# 75%      91.000000
# max    9062.000000
# [   data
# 0    68
# 1    72
# 2    77
# 3    85
# 4    85
# 5    85
# 6    91
# 7    95
# 8  9062]
